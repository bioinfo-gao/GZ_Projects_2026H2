# %% [markdown]
# Motherboard ROG Zenithe alpha
# Have a 0.8cm x 4 cm LED display
# Have start key
# have reset key
#
# In the bottom have 2 tiny swtich
#
# 拨动 SLOW_MODE 开关：
# 在完全断电的状态下，将底部的 SLOW_MODE 开关拨到 ON。

# %% [markdown]
# Corsair Hydro-cooler H100i RGB Platinum cooler for AMD Ryzen 5 1600X 9060-039ww

# %% [markdown]
# https://aistudio.google.com/prompts/16YqYXDFkLifkGF3pVCRIxTwge8I7KSIb

# %% [markdown]
# 修复了硬件底层供电自锁：通过彻底断电和 BIOS Flashback（盲刷）救回了主板“大脑”。
# 找回了 128GB 内存：通过“单兵侦察”排除法，擦拭金手指，确认了所有 8 根内存条的健康。
# 恢复了高效散热：在水冷受损的情况下，成功隔离信号干扰并恢复水泵动力。
# 实现了专业级“无头”运维：在 BIOS 里彻底封印了报错，让服务器实现了断电自启和无人值守启动。
# 🛡️ 给你的最后三条“老兵建议”：
# 立即运行一次全量备份：
# 虽然数据现在看起来很安全，但服务器经历了剧烈的电涌和反复的开关机测试。建议现在趁系统稳定，立刻运行一次 rsync 或你的备份脚本，确保万无一失。
# 安装监控工具：
# 既然是无头服务器，建议安装 netdata 或 glances。这样你只需要打开浏览器，就能随时监控这台猛兽的温度、内存压力和硬盘健康，不用每次都去敲命令。
# 封印那个“硬件杀手”：
# 请务必把那个引发灾难的 Type-C 硬盘盒 彻底处理掉。它不仅是这次事故的元凶，更证明了它存在严重的电气设计缺陷。
# 你现在的感觉一定非常棒。这不仅是省下了几千美金的维修费和买新服务器的钱，更重要的是，你通过这次“实战测试”，对这台服务器的每一个插槽、每一根线缆、每一个 BIOS 选项都了如指掌。
# 现在，请放心去休息吧！你的服务器已经重新成为了你的数字化堡垒。向你这位硬核的硬件大师致敬！祝你的 Linux 服务器运行永不宕机！

# %% [markdown]
# 完成的任务清单：
#
# 解决 5V 供电短路故障
#
# 盲刷 BIOS 恢复受损固件
#
# 找回 128GB 内存（排除坏道）
#
# 物理恢复散热与风扇控制
#
# 挂载 120TB+ 存储阵列
#
# 完成无头服务器自动化配置
# 你已经把这台机器从一堆“电子废铁”修成了“工业级服务器”。 既然数据都备份了，现在就去享受这种“掌控全局”的成就感吧！去执行最后的合体，然后好好休息！
