# %% [markdown]
# | Skill / MCP | 类型 | 核心功能 | 与你的相关度 |
# | :--- | :---: | :---: | :---: |
# | `single-cell-rna-qc` | Skill | 遵循 scverse 最佳实践，MAD-based 过滤 + 完整 QC 可视化 | ⭐⭐⭐⭐⭐ |
# | `nextflow-development` | Skill | 运行 nf-core 流程（rnaseq / sarek / atacseq），支持本地或 GEO/SRA 数据 | ⭐⭐⭐⭐⭐ |
# | `scvi-tools` | Skill | scVI、scANVI、totalVI、MultiVI 等深度学习单细胞整合分析 | ⭐⭐⭐⭐ |
# | `scientific-problem-selection` | Skill | 帮助界定研究问题、优先级排序 | ⭐⭐⭐ |
# | `10x-genomics` | MCP Server | 访问 10x Genomics Cloud 分析数据和工作流 | ⭐⭐⭐⭐ |
# | `pubmed` | MCP Server | 检索 PubMed 生物医学文献，免认证 | ⭐⭐⭐⭐⭐ |
# | `biorender` | MCP Server | 生成科学插图（需免费 BioRender 账号） | ⭐⭐⭐ |
# | `synapse` | MCP Server | 访问 Synapse 平台数据集（需机构账号） | ⭐⭐ |
