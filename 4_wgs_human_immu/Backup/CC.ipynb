# %% [markdown]
# 请自主安装调试 wgs nf-core 标准程序，并测试样本数据, 各项教程，文本，输入输出，配置可以暂时存放于 /home/gao/projects_2026H2/4_wgs_human_immu          我给予你全部权限，请自主执行，就记录各项关键操作以备我查阅和调试即可

# %% [markdown]
# Update Todos

# %% [markdown]
# Set up project directory structure under 4_wgs_human_immu
#
# Install nf-core/tools CLI in regular_bioinfo conda env
#
# Write resource-capped nextflow config (house style) for sarek
#
# Run nf-core/sarek test profile (test,singularity) as sample-data validation
#
# Monitor run to completion, capture logs/errors, debug as needed
#
# Write Chinese tutorial/doc for future real human WGS runs (samplesheet, genome refs, tools)
#
# Write key-operations log file for user review

# %% [markdown]
# 请自主安装调试 wgs nf-core 标准程序，并测试样本数据, 各项教程，文本，输入输出，配置可以暂时存放于 /home/gao/projects_2026H2/4_wgs_human_immu          我给予你全部权限，请自主执行，就记录各项关键操作以备我查阅和调试即可
